# %% [markdown]
# # US EPA AQI Data Acquisition
# This example illustrates how to request data from the US Environmental Protection Agency (EPA) Air Quality Service (AQS) API. This is a historical API and does not provide real-time air quality data. The [documentation](https://aqs.epa.gov/aqsweb/documents/data_api.html) for the API provides definitions of the different call parameter and examples of the various calls that can be made to the API.
#
# This notebook works systematically through example calls, requesting an API key, using 'list' to get various IDs and parameter values, and using 'daily summary' to get summary data that meets specific condistions. The notebook contains example function definitions that could be reused in other code. In general, the notebook explains each step along the way, referring back to possible output. Some of the explanations are tailored to the specific example requests of the API. Changing values to explore the results of the API is probably useful, but that will result in some explanations being out of sync with the outputs.
#
# The US EPA was created in the early 1970's. The EPA reports that they only started broad based monitoring with standardized quality assurance procedures in the 1980's. Many counties will have data starting somewhere between 1983 and 1988. However, some counties still do not have any air quality monitoring stations. The API helps resolve this by providing calls to search for monitoring stations and data using either station ids, or a county designation or a geographic bounding box. This example code provides examples of the county based and bounding box based API calls. Some [additional information on the Air Quality System can be found in the EPA FAQ](https://www.epa.gov/outdoor-air-quality-data/frequent-questions-about-airdata) on the system.
#
# The end goal of this example is to get to some values that we might use for the Air Quality Index or AQI. You might see this reported on the news, most often around smog, but more frequently with regard to smoke. The AQI index is meant to tell us something about how healthy or clean the air is on any day. The AQI is actually a somewhat complext measure. When I started this example I looked up [how to calculate the AQI](https://www.airnow.gov/sites/default/files/2020-05/aqi-technical-assistance-document-sept2018.pdf) so that I would know roughly what goes into that value.
#
#
# ## License
# This code example was developed by Dr. David W. McDonald for use in DATA 512, a course in the UW MS Data Science degree program. This code is provided under the [Creative Commons](https://creativecommons.org) [CC-BY license](https://creativecommons.org/licenses/by/4.0/). Revision 1.1 - September 5, 2023

# %%
# 
#    These are standard python modules
#
#import json, time, urllib.parse
import json, time
#
#    The 'requests' module is a distribution module for making web requests.
#
import requests

# %%
#########
#
#    CONSTANTS
#

#
#    This is the root of all AQS API URLs
#
API_REQUEST_URL = 'https://aqs.epa.gov/data/api'

#
#    These are 'actions' we can ask the API to take or requests that we can make of the API
#
#    Sign-up request - generally only performed once - unless you lose your key
API_ACTION_SIGNUP = '/signup?email={email}'
#
#    List actions provide information on API parameter values that are required by some other actions/requests
API_ACTION_LIST_CLASSES = '/list/classes?email={email}&key={key}'
API_ACTION_LIST_PARAMS = '/list/parametersByClass?email={email}&key={key}&pc={pclass}'
API_ACTION_LIST_SITES = '/list/sitesByCounty?email={email}&key={key}&state={state}&county={county}'
#
#    Monitor actions are requests for monitoring stations that meet specific criteria
API_ACTION_MONITORS_COUNTY = '/monitors/byCounty?email={email}&key={key}&param={param}&bdate={begin_date}&edate={end_date}&state={state}&county={county}'
API_ACTION_MONITORS_BOX = '/monitors/byBox?email={email}&key={key}&param={param}&bdate={begin_date}&edate={end_date}&minlat={minlat}&maxlat={maxlat}&minlon={minlon}&maxlon={maxlon}'
#
#    Summary actions are requests for summary data. These are for daily summaries
API_ACTION_DAILY_SUMMARY_COUNTY = '/dailyData/byCounty?email={email}&key={key}&param={param}&bdate={begin_date}&edate={end_date}&state={state}&county={county}'
API_ACTION_DAILY_SUMMARY_BOX = '/dailyData/byBox?email={email}&key={key}&param={param}&bdate={begin_date}&edate={end_date}&minlat={minlat}&maxlat={maxlat}&minlon={minlon}&maxlon={maxlon}'
#
#    It is always nice to be respectful of a free data resource.
#    We're going to observe a 100 requests per minute limit - which is fairly nice
API_LATENCY_ASSUMED = 0.002       # Assuming roughly 2ms latency on the API and network
API_THROTTLE_WAIT = (1.0/100.0)-API_LATENCY_ASSUMED
#
#
#    This is a template that covers most of the parameters for the actions we might take, from the set of actions
#    above. In the examples below, most of the time parameters can either be supplied as individual values to a
#    function - or they can be set in a copy of the template and passed in with the template.
# 
AQS_REQUEST_TEMPLATE = {
    "email":      "",     
    "key":        "",      
    "state":      "",     # the two digit state FIPS # as a string
    "county":     "",     # the three digit county FIPS # as a string
    "begin_date": "",     # the start of a time window in YYYYMMDD format
    "end_date":   "",     # the end of a time window in YYYYMMDD format, begin_date and end_date must be in the same year
    "minlat":    0.0,
    "maxlat":    0.0,
    "minlon":    0.0,
    "maxlon":    0.0,
    "param":     "",     # a list of comma separated 5 digit codes, max 5 codes requested
    "pclass":    ""      # parameter class is only used by the List calls
}

# %% [markdown]
# ## Making a sign-up request
#
# Before you can use the API you need to request a key. You will use an email address to make the request. The EPA then sends a confirmation email link and a 'key' that you use for all other requests.
#
# You only need to sign-up once, unless you want to invalidate your current key (by getting a new key) or you lose your key.

# %%
#
#    This implements the sign-up request. The parameters are standardized so that this function definition matches
#    all of the others. However, the easiest way to call this is to simply call this function with your preferred
#    email address.
#
def request_signup(email_address = None,
                   endpoint_url = API_REQUEST_URL, 
                   endpoint_action = API_ACTION_SIGNUP, 
                   request_template = AQS_REQUEST_TEMPLATE,
                   headers = None):
    
    # Make sure we have a string - if you don't have access to this email addres, things might go badly for you
    if email_address:
        request_template['email'] = email_address        
    if not request_template['email']: 
        raise Exception("Must supply an email address to call 'request_signup()'")
    
    # Compose the signup url - create a request URL by combining the endpoint_url with the parameters for the request
    request_url = endpoint_url+endpoint_action.format(**request_template)
        
    # make the request
    try:
        # Wait first, to make sure we don't exceed a rate limit in the situation where an exception occurs
        # during the request processing - throttling is always a good practice with a free data source
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %%
#
#    A SIGNUP request is only to be done once, to request a key. A key is sent to that email address and needs to be confirmed with a click through
#    This code should probably be commented out after you've made your key request to make sure you don't accidentally make a new sign-up request
#
print("Requesting SIGNUP ...")
response = request_signup("mshash@uw.edu")
print(json.dumps(response,indent=4))
#
# Out:
# Requesting SIGNUP ...
# {
#     "Header": [
#         {
#             "status": "Success",
#             "request_time": "2023-11-07T17:01:20-05:00",
#             "url": "https://aqs.epa.gov/data/api/signup?email=mshash@uw.edu"
#         }
#     ],
#     "Data": [
#         "You should receive an email containing your new key shortly."
#     ]
# }

# %% [markdown]
# A response to the signup request might look something like this.
#
#
#     Requesting SIGNUP ...
#     {
#         "Header": [
#             {
#                 "status": "Success",
#                 "request_time": "2023-08-07T17:03:27-04:00",
#                 "url": "https://aqs.epa.gov/data/api/signup?email=dwmc@uw.edu"
#             }
#         ],
#         "Data": [
#             "You should receive a registration confirmation email with a link for confirming your email shortly."
#         ]
#     }

# %%
USERNAME = "mshash@uw.edu"
APIKEY = "xxxxxx"

# %%
#
#   Once we have a list of the classes or groups of possible sensors, we can find the sensor IDs that make up that class (group)
#   The one that looks to be associated with the Air Quality Index is "AQI POLLUTANTS"
#   We'll use that to make another list request.
#
AQI_PARAM_CLASS = "AQI POLLUTANTS"

# %%
#
#   Given the set of sensor codes, now we can create a parameter list or 'param' value as defined by the AQS API spec.
#   It turns out that we want all of these measures for AQI, but we need to have two different param constants to get
#   all seven of the code types. We can only have a max of 5 sensors/values request per param.
#
#   Gaseous AQI pollutants CO, SO2, NO2, and O2
AQI_PARAMS_GASEOUS = "42101,42401,42602,44201"
#
#   Particulate AQI pollutants PM10, PM2.5, and Acceptable PM2.5
AQI_PARAMS_PARTICULATES = "81102,88101,88502"
#   
#

# %% [markdown]
# Air quality monitoring stations are located all over the US at different locations. We will need some sample locations to experiment with different locations to see what kinds of values come back from different sensor requests.
#
# This list includes the [FIPS](https://www.census.gov/library/reference/code-lists/ansi.html) number for the state and county as a 5 digit string. This format, the 5 digit string, is a 'old' format that is still widely used. There are new codes that may eventually be adopted for the US government information systems. But FIPS is currently what the AQS uses, so that's what is in the list as the constant.

# %%
#
#   Defining the city under study - Lewiston, Idaho by its coordinates and FIPS number
#

CITY_LOCATIONS = {
    'lw' :       {'city'   : 'Lewiston',
                       'county' : 'Nez Perce',
                       'state'  : 'Idaho',
                       'fips'   : '46540',
                       'latlon' : [46.4004, -117.0012] }
}

# %% [markdown]
# Given our CITY_LOCATIONS constant we can now find which monitoring locations are nearby. One option is to use the county to define the area we're interest in. You can get the EPA to list their monitoring stations by county. You can also get a set of monitoring stations by using a bounding box of latitude, longitude points. For this example, we'll use the county approach. There is a bounding box example later in this notebook.

# %% [markdown]
# ## Making a daily summary request
#
# The function below is designed to encapsulate requests to the EPA AQS API. When calling the function one should create/copy a parameter template, then initialize that template with values that won't change with each call. Then on each call simply pass in the parameters that need to change, like date ranges.
#
# Another function below provides an example of extracting values and restructuring the response to make it a little more usable.

# %%
#
#    This implements the daily summary request. Daily summary provides a daily summary value for each sensor being requested
#    from the start date to the end date. 
#
#    Like the two other functions, this can be called with a mixture of a defined parameter dictionary, or with function
#    parameters. If function parameters are provided, those take precedence over any parameters from the request template.
#
def request_daily_summary(email_address = None, key = None, param=None,
                          begin_date = None, end_date = None, fips = None,
                          endpoint_url = API_REQUEST_URL, 
                          endpoint_action = API_ACTION_DAILY_SUMMARY_COUNTY, 
                          request_template = AQS_REQUEST_TEMPLATE,
                          headers = None):
    
    #  This prioritizes the info from the call parameters - not what's already in the template
    if email_address:
        request_template['email'] = email_address
    if key:
        request_template['key'] = key
    if param:
        request_template['param'] = param
    if begin_date:
        request_template['begin_date'] = begin_date
    if end_date:
        request_template['end_date'] = end_date
    if fips and len(fips)==5:
        request_template['state'] = fips[:2]
        request_template['county'] = fips[2:]            

    # Make sure there are values that allow us to make a call - these are always required
    if not request_template['email']:
        raise Exception("Must supply an email address to call 'request_daily_summary()'")
    if not request_template['key']: 
        raise Exception("Must supply a key to call 'request_daily_summary()'")
    if not request_template['param']: 
        raise Exception("Must supply param values to call 'request_daily_summary()'")
    if not request_template['begin_date']: 
        raise Exception("Must supply a begin_date to call 'request_daily_summary()'")
    if not request_template['end_date']: 
        raise Exception("Must supply an end_date to call 'request_daily_summary()'")
    # Note we're not validating FIPS fields because not all of the daily summary actions require the FIPS numbers
        
    # compose the request
    request_url = endpoint_url+endpoint_action.format(**request_template)
        
    # make the request
    try:
        # Wait first, to make sure we don't exceed a rate limit in the situation where an exception occurs
        # during the request processing - throttling is always a good practice with a free data source
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %%
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY
request_data['param'] = AQI_PARAMS_GASEOUS
request_data['state'] = CITY_LOCATIONS['lw']['fips'][:2]
request_data['county'] = CITY_LOCATIONS['lw']['fips'][2:]

# request daily summary data for the month of July in 2021
gaseous_aqi = request_daily_summary(request_template=request_data, begin_date="20210701", end_date="20210731")
print("Response for the gaseous pollutants ...")
#
if gaseous_aqi["Header"][0]['status'] == "Success":
    print(json.dumps(gaseous_aqi['Data'],indent=4))
elif gaseous_aqi["Header"][0]['status'].startswith("No data "):
    print("Looks like the response generated no data. You might take a closer look at your request and the response data.")
else:
    print(json.dumps(gaseous_aqi,indent=4))

request_data['param'] = AQI_PARAMS_PARTICULATES
# request daily summary data for the month of July in 2021
particulate_aqi = request_daily_summary(request_template=request_data, begin_date="20210701", end_date="20210731")
print("Response for the particulate pollutants ...")
#
if particulate_aqi["Header"][0]['status'] == "Success":
    print(json.dumps(particulate_aqi['Data'],indent=4))
elif particulate_aqi["Header"][0]['status'].startswith("No data "):
    print("Looks like the response generated no data. You might take a closer look at your request and the response data.")
else:
    print(json.dumps(particulate_aqi,indent=4))
# Out:
# Response for the gaseous pollutants ...
# Looks like the response generated no data. You might take a closer look at your request and the response data.
# Response for the particulate pollutants ...
# Looks like the response generated no data. You might take a closer look at your request and the response data.

# %% [markdown]
# This response shows that there are no stations at the city under study

# %% [markdown]
# ## Find stations with close to the destination that have data

# %%
#
#   These are rough estimates for creating bounding boxes based on a city location
#   You can find these rough estimates on the USGS website:
#   https://www.usgs.gov/faqs/how-much-distance-does-a-degree-minute-and-second-cover-your-maps
#
LAT_25MILES = 25.0 * (1.0/69.0)    # This is about 25 miles of latitude in decimal degrees
LON_25MILES = 25.0 * (1.0/54.6)    # This is about 25 miles of longitude in decimal degrees
#
#   Compute a rough estimates for a bounding box around a given place
#   The bounding box is scaled in 50 mile increments. That is the bounding box will have sides that
#   are rough multiples of 50 miles, with the center of the box around the indicated place.
#   The scale parameter determines the scale (size) of the bounding box
#
def bounding_latlon(place=None,scale=1.0):
    minlat = place['latlon'][0] - float(scale) * LAT_25MILES
    maxlat = place['latlon'][0] + float(scale) * LAT_25MILES
    minlon = place['latlon'][1] - float(scale) * LON_25MILES
    maxlon = place['latlon'][1] + float(scale) * LON_25MILES
    return [minlat,maxlat,minlon,maxlon]

# %%
#
#    This implements the monitors request. This requests monitoring stations. This can be done by state, county, or bounding box. 
#
#    Like the two other functions, this can be called with a mixture of a defined parameter dictionary, or with function
#    parameters. If function parameters are provided, those take precedence over any parameters from the request template.
#
def request_monitors(email_address = None, key = None, param=None,
                          begin_date = None, end_date = None, fips = None,
                          endpoint_url = API_REQUEST_URL, 
                          endpoint_action = API_ACTION_MONITORS_COUNTY, 
                          request_template = AQS_REQUEST_TEMPLATE,
                          headers = None):
    
    #  This prioritizes the info from the call parameters - not what's already in the template
    if email_address:
        request_template['email'] = email_address
    if key:
        request_template['key'] = key
    if param:
        request_template['param'] = param
    if begin_date:
        request_template['begin_date'] = begin_date
    if end_date:
        request_template['end_date'] = end_date
    if fips and len(fips)==5:
        request_template['state'] = fips[:2]
        request_template['county'] = fips[2:]            

    # Make sure there are values that allow us to make a call - these are always required
    if not request_template['email']:
        raise Exception("Must supply an email address to call 'request_monitors()'")
    if not request_template['key']: 
        raise Exception("Must supply a key to call 'request_monitors()'")
    if not request_template['param']: 
        raise Exception("Must supply param values to call 'request_monitors()'")
    if not request_template['begin_date']: 
        raise Exception("Must supply a begin_date to call 'request_monitors()'")
    if not request_template['end_date']: 
        raise Exception("Must supply an end_date to call 'request_monitors()'")
    # Note we're not validating FIPS fields because not all of the monitors actions require the FIPS numbers
    
    # compose the request
    request_url = endpoint_url+endpoint_action.format(**request_template)
    
    # make the request
    try:
        # Wait first, to make sure we don't exceed a rate limit in the situation where an exception occurs
        # during the request processing - throttling is always a good practice with a free data source
        if API_THROTTLE_WAIT > 0.0:
            time.sleep(API_THROTTLE_WAIT)
        response = requests.get(request_url, headers=headers)
        json_response = response.json()
    except Exception as e:
        print(e)
        json_response = None
    return json_response

# %%
#
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY
request_data['param'] = AQI_PARAMS_PARTICULATES     # remember we have both gaseous and particulates
# 
request_data['state'] = CITY_LOCATIONS['lw']['fips'][:2]
request_data['county'] = CITY_LOCATIONS['lw']['fips'][2:]
#
response = request_monitors(request_template=request_data, begin_date="20210701", end_date="20210731")
if response["Header"][0]['status'] == "Success":
    print(json.dumps(response['Data'],indent=4))
else:
    print(json.dumps(response,indent=4))
# Out:
# {
#     "Header": [
#         {
#             "status": "No data matched your selection",
#             "request_time": "2023-11-08T17:27:10-05:00",
#             "url": "https://aqs.epa.gov/data/api/monitors/byCounty?email=mshash@uw.edu&key=berryfrog85&param=81102,88101,88502&bdate=20210701&edate=20210731&state=46&county=540",
#             "rows": 0
#         }
#     ],
#     "Data": []
# }

# %% [markdown]
# This shows that there are no monitors in Lewiston, Idaho

# %%
#
#    Create a copy of the AQS_REQUEST_TEMPLATE
#
request_data = AQS_REQUEST_TEMPLATE.copy()
request_data['email'] = USERNAME
request_data['key'] = APIKEY
request_data['param'] = AQI_PARAMS_PARTICULATES     # particulate request 

#   50 mile box
bbox = bounding_latlon(CITY_LOCATIONS['lw'],scale=1.0)

#   put our bounding box into the request_data
request_data['minlat'] = bbox[0]
request_data['maxlat'] = bbox[1]
request_data['minlon'] = bbox[2]
request_data['maxlon'] = bbox[3]

#
#   we need to change the action for the API from the default to the bounding box - this includes date of the study
response = request_monitors(request_template=request_data, begin_date="19630101", end_date="20230131",
                            endpoint_action = API_ACTION_MONITORS_BOX)
#
#
#
if response["Header"][0]['status'] == "Success":
    print(json.dumps(response['Data'],indent=4))
else:
    print(json.dumps(response,indent=4))
# Out:
# [
#     {
#         "state_code": "16",
#         "county_code": "069",
#         "site_number": "0009",
#         "parameter_code": "88101",
#         "poc": 1,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "1999-10-04",
#         "close_date": "2003-06-26",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "117",
#         "last_method_description": "R & P Model 2000 PM2.5 Sampler w/WINS - GRAVIMETRIC",
#         "last_method_begin_date": "1999-10-04",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0511",
#         "monitoring_agency": "Idaho Department Of Health And Welfare-Environment Division",
#         "si_id": 3575,
#         "latitude": 46.417778,
#         "longitude": -117.018611,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 225.0,
#         "probe_height": 13.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": null,
#         "address": "STATE OFFICE BLDG/1118 F ST",
#         "state_name": "Idaho",
#         "county_name": "Nez Perce",
#         "city_name": "Lewiston",
#         "cbsa_code": "30300",
#         "cbsa_name": "Lewiston, ID-WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": "182",
#         "tribe_name": "Nez Perce Tribe, Idaho"
#     },
#     {
#         "state_code": "16",
#         "county_code": "069",
#         "site_number": "0009",
#         "parameter_code": "88101",
#         "poc": 2,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2000-07-01",
#         "close_date": "2003-06-26",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "117",
#         "last_method_description": "R & P Model 2000 PM2.5 Sampler w/WINS - GRAVIMETRIC",
#         "last_method_begin_date": "2000-07-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0511",
#         "monitoring_agency": "Idaho Department Of Health And Welfare-Environment Division",
#         "si_id": 3575,
#         "latitude": 46.417778,
#         "longitude": -117.018611,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 225.0,
#         "probe_height": 11.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": null,
#         "address": "STATE OFFICE BLDG/1118 F ST",
#         "state_name": "Idaho",
#         "county_name": "Nez Perce",
#         "city_name": "Lewiston",
#         "cbsa_code": "30300",
#         "cbsa_name": "Lewiston, ID-WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": "182",
#         "tribe_name": "Nez Perce Tribe, Idaho"
#     },
#     {
#         "state_code": "53",
#         "county_code": "075",
#         "site_number": "0003",
#         "parameter_code": "88502",
#         "poc": 4,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2002-10-01",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "771",
#         "last_method_description": "Correlated Radiance Research M903 With Heated Inlet - Nephelometry",
#         "last_method_begin_date": "2018-06-20",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "1136",
#         "monitoring_agency": "Washington State Department Of Ecology",
#         "si_id": 16816,
#         "latitude": 46.72447,
#         "longitude": -117.18014,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 109305.56,
#         "elevation": 771.0,
#         "probe_height": 5.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": " PULLMAN - DEXTER AVE 4",
#         "address": "240 SE DEXTER (Pullman Administration Building)",
#         "state_name": "Washington",
#         "county_name": "Whitman",
#         "city_name": "Pullman",
#         "cbsa_code": "39420",
#         "cbsa_name": "Pullman, WA",
#         "csa_code": "446",
#         "csa_name": "Pullman-Moscow, WA-ID",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "16",
#         "county_code": "069",
#         "site_number": "0012",
#         "parameter_code": "88502",
#         "poc": 3,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2004-03-05",
#         "close_date": "2016-02-26",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "716",
#         "last_method_description": "PM2.5 VSCC w/No Correction Factor - TEOM Gravimetric 50 deg C",
#         "last_method_begin_date": "2015-04-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0511",
#         "monitoring_agency": "Idaho Department Of Health And Welfare-Environment Division",
#         "si_id": 3578,
#         "latitude": 46.408352,
#         "longitude": -116.992533,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 30.36,
#         "elevation": 284.988,
#         "probe_height": 2.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": "Lewiston",
#         "address": "1200 29TH STREET",
#         "state_name": "Idaho",
#         "county_name": "Nez Perce",
#         "city_name": "Lewiston",
#         "cbsa_code": "30300",
#         "cbsa_name": "Lewiston, ID-WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": "182",
#         "tribe_name": "Nez Perce Tribe, Idaho"
#     },
#     {
#         "state_code": "16",
#         "county_code": "069",
#         "site_number": "0006",
#         "parameter_code": "81102",
#         "poc": 2,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "2006-05-01",
#         "close_date": "2007-04-30",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "MIDDLE SCALE",
#         "measurement_scale_def": "100 M TO 500 M",
#         "monitoring_objective": "GENERAL/BACKGROUND",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "2006-05-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "182",
#         "monitoring_agency": "Nez Perce Tribe, Idaho",
#         "si_id": 3572,
#         "latitude": 46.429561,
#         "longitude": -116.992427,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 0.0,
#         "probe_height": null,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": null,
#         "address": "ISP BLDG/2700 N/S HWY 12-95",
#         "state_name": "Idaho",
#         "county_name": "Nez Perce",
#         "city_name": "Lewiston",
#         "cbsa_code": "30300",
#         "cbsa_name": "Lewiston, ID-WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": "182",
#         "tribe_name": "Nez Perce Tribe, Idaho"
#     },
#     {
#         "state_code": "16",
#         "county_code": "069",
#         "site_number": "0012",
#         "parameter_code": "88502",
#         "poc": 4,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2016-03-08",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "731",
#         "last_method_description": "Met-One BAM-1020 W/PM2.5 SCC - Beta Attenuation",
#         "last_method_begin_date": "2016-03-08",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SPM",
#         "networks": null,
#         "monitoring_agency_code": "0511",
#         "monitoring_agency": "Idaho Department Of Health And Welfare-Environment Division",
#         "si_id": 3578,
#         "latitude": 46.408352,
#         "longitude": -116.992533,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 30.36,
#         "elevation": 284.988,
#         "probe_height": 2.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": "Lewiston",
#         "address": "1200 29TH STREET",
#         "state_name": "Idaho",
#         "county_name": "Nez Perce",
#         "city_name": "Lewiston",
#         "cbsa_code": "30300",
#         "cbsa_name": "Lewiston, ID-WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": "182",
#         "tribe_name": "Nez Perce Tribe, Idaho"
#     },
#     {
#         "state_code": "16",
#         "county_code": "069",
#         "site_number": "0009",
#         "parameter_code": "81102",
#         "poc": 2,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1986-01-01",
#         "close_date": "1987-12-31",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": null,
#         "measurement_scale_def": null,
#         "monitoring_objective": "UNKNOWN",
#         "last_method_code": "052",
#         "last_method_description": "HI-VOL-SA321A - GRAVIMETRIC",
#         "last_method_begin_date": "1986-01-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0511",
#         "monitoring_agency": "Idaho Department Of Health And Welfare-Environment Division",
#         "si_id": 3575,
#         "latitude": 46.417778,
#         "longitude": -117.018611,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 225.0,
#         "probe_height": 11.0,
#         "pl_probe_location": null,
#         "local_site_name": null,
#         "address": "STATE OFFICE BLDG/1118 F ST",
#         "state_name": "Idaho",
#         "county_name": "Nez Perce",
#         "city_name": "Lewiston",
#         "cbsa_code": "30300",
#         "cbsa_name": "Lewiston, ID-WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": "182",
#         "tribe_name": "Nez Perce Tribe, Idaho"
#     },
#     {
#         "state_code": "53",
#         "county_code": "003",
#         "site_number": "0004",
#         "parameter_code": "88101",
#         "poc": 1,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2007-03-28",
#         "close_date": "2008-03-31",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "117",
#         "last_method_description": "R & P Model 2000 PM2.5 Sampler w/WINS - GRAVIMETRIC",
#         "last_method_begin_date": "2007-03-28",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "1136",
#         "monitoring_agency": "Washington State Department Of Ecology",
#         "si_id": 16455,
#         "latitude": 46.425416,
#         "longitude": -117.060445,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 5.0,
#         "elevation": 250.0,
#         "probe_height": 6.0,
#         "pl_probe_location": null,
#         "local_site_name": "CLARKSTON - 13TH ST",
#         "address": "13TH ST AND PORT WAY (CLARKSTON STP)",
#         "state_name": "Washington",
#         "county_name": "Asotin",
#         "city_name": "Clarkston",
#         "cbsa_code": "30300",
#         "cbsa_name": "Lewiston, ID-WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "16",
#         "county_code": "069",
#         "site_number": "0222",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "2006-05-01",
#         "close_date": "2007-04-30",
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "URBAN SCALE",
#         "measurement_scale_def": "4 KM TO 50 KM",
#         "monitoring_objective": "SOURCE ORIENTED",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "2006-05-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "182",
#         "monitoring_agency": "Nez Perce Tribe, Idaho",
#         "si_id": 93418,
#         "latitude": 46.438089,
#         "longitude": -116.905182,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.6,
#         "elevation": 235.53,
#         "probe_height": 2.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": null,
#         "address": "17500 NEZ PERCE ROAD",
#         "state_name": "Idaho",
#         "county_name": "Nez Perce",
#         "city_name": "Not in a city",
#         "cbsa_code": "30300",
#         "cbsa_name": "Lewiston, ID-WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": "182",
#         "tribe_name": "Nez Perce Tribe, Idaho"
#     },
#     {
#         "state_code": "16",
#         "county_code": "069",
#         "site_number": "0009",
#         "parameter_code": "81102",
#         "poc": 3,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "2006-05-01",
#         "close_date": "2007-04-30",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "GENERAL/BACKGROUND",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "2006-05-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "182",
#         "monitoring_agency": "Nez Perce Tribe, Idaho",
#         "si_id": 3575,
#         "latitude": 46.417778,
#         "longitude": -117.018611,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 225.0,
#         "probe_height": null,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": null,
#         "address": "STATE OFFICE BLDG/1118 F ST",
#         "state_name": "Idaho",
#         "county_name": "Nez Perce",
#         "city_name": "Lewiston",
#         "cbsa_code": "30300",
#         "cbsa_name": "Lewiston, ID-WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": "182",
#         "tribe_name": "Nez Perce Tribe, Idaho"
#     },
#     {
#         "state_code": "16",
#         "county_code": "069",
#         "site_number": "0012",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "2006-05-01",
#         "close_date": "2007-04-30",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "GENERAL/BACKGROUND",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "2006-05-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "182",
#         "monitoring_agency": "Nez Perce Tribe, Idaho",
#         "si_id": 3578,
#         "latitude": 46.408352,
#         "longitude": -116.992533,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 30.36,
#         "elevation": 284.988,
#         "probe_height": 2.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": "Lewiston",
#         "address": "1200 29TH STREET",
#         "state_name": "Idaho",
#         "county_name": "Nez Perce",
#         "city_name": "Lewiston",
#         "cbsa_code": "30300",
#         "cbsa_name": "Lewiston, ID-WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": "182",
#         "tribe_name": "Nez Perce Tribe, Idaho"
#     },
#     {
#         "state_code": "53",
#         "county_code": "003",
#         "site_number": "0004",
#         "parameter_code": "88101",
#         "poc": 5,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2019-12-03",
#         "close_date": "2019-12-03",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "209",
#         "last_method_description": "Met One BAM-1022 Mass Monitor w/ VSCC or TE-PM2.5C - Beta Attenuation",
#         "last_method_begin_date": "2019-12-03",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "1136",
#         "monitoring_agency": "Washington State Department Of Ecology",
#         "si_id": 16455,
#         "latitude": 46.425416,
#         "longitude": -117.060445,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 5.0,
#         "elevation": 250.0,
#         "probe_height": 3.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": "CLARKSTON - 13TH ST",
#         "address": "13TH ST AND PORT WAY (CLARKSTON STP)",
#         "state_name": "Washington",
#         "county_name": "Asotin",
#         "city_name": "Clarkston",
#         "cbsa_code": "30300",
#         "cbsa_name": "Lewiston, ID-WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "53",
#         "county_code": "075",
#         "site_number": "0003",
#         "parameter_code": "88502",
#         "poc": 8,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2020-01-23",
#         "close_date": "2022-11-30",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "171",
#         "last_method_description": "Met-one BAM-1022 W/PM2.5 SCC - Beta Attenuation",
#         "last_method_begin_date": "2020-01-23",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "1136",
#         "monitoring_agency": "Washington State Department Of Ecology",
#         "si_id": 16816,
#         "latitude": 46.72447,
#         "longitude": -117.18014,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 109305.56,
#         "elevation": 771.0,
#         "probe_height": 5.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": " PULLMAN - DEXTER AVE 4",
#         "address": "240 SE DEXTER (Pullman Administration Building)",
#         "state_name": "Washington",
#         "county_name": "Whitman",
#         "city_name": "Pullman",
#         "cbsa_code": "39420",
#         "cbsa_name": "Pullman, WA",
#         "csa_code": "446",
#         "csa_name": "Pullman-Moscow, WA-ID",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "53",
#         "county_code": "003",
#         "site_number": "0003",
#         "parameter_code": "81102",
#         "poc": 2,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1988-07-15",
#         "close_date": "1993-06-16",
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "HIGHEST CONCENTRATION",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "1988-07-15",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "1136",
#         "monitoring_agency": "Washington State Department Of Ecology",
#         "si_id": 16454,
#         "latitude": 46.409605,
#         "longitude": -117.045991,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 256.0,
#         "probe_height": 7.0,
#         "pl_probe_location": null,
#         "local_site_name": null,
#         "address": "CF ADAMS HIGH/5TH & CHESTNUT",
#         "state_name": "Washington",
#         "county_name": "Asotin",
#         "city_name": "Clarkston",
#         "cbsa_code": "30300",
#         "cbsa_name": "Lewiston, ID-WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "16",
#         "county_code": "057",
#         "site_number": "0005",
#         "parameter_code": "88101",
#         "poc": 1,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2002-07-01",
#         "close_date": "2003-06-26",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "URBAN SCALE",
#         "measurement_scale_def": "4 KM TO 50 KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "117",
#         "last_method_description": "R & P Model 2000 PM2.5 Sampler w/WINS - GRAVIMETRIC",
#         "last_method_begin_date": "2002-07-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0511",
#         "monitoring_agency": "Idaho Department Of Health And Welfare-Environment Division",
#         "si_id": 3558,
#         "latitude": 46.72182,
#         "longitude": -116.960177,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 30.36,
#         "elevation": 800.7096,
#         "probe_height": 2.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": "Moscow",
#         "address": "1025 PLANT SCIENCES ROAD",
#         "state_name": "Idaho",
#         "county_name": "Latah",
#         "city_name": "Moscow",
#         "cbsa_code": "34140",
#         "cbsa_name": "Moscow, ID",
#         "csa_code": "446",
#         "csa_name": "Pullman-Moscow, WA-ID",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "16",
#         "county_code": "069",
#         "site_number": "0013",
#         "parameter_code": "88502",
#         "poc": 3,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2015-10-01",
#         "close_date": "2019-01-07",
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "REGIONAL SCALE",
#         "measurement_scale_def": "50 TO HUNDREDS KM",
#         "monitoring_objective": "GENERAL/BACKGROUND",
#         "last_method_code": "701",
#         "last_method_description": "PM2.5 SCC w/No Correction Factor - TEOM Gravimetric 50 deg C",
#         "last_method_begin_date": "2003-04-26",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "182",
#         "monitoring_agency": "Nez Perce Tribe, Idaho",
#         "si_id": 91734,
#         "latitude": 46.3972,
#         "longitude": -116.8062,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 2.0,
#         "elevation": 339.14,
#         "probe_height": 4.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": null,
#         "address": "260 BEVER GRADE, LAPWAI",
#         "state_name": "Idaho",
#         "county_name": "Nez Perce",
#         "city_name": "Not in a city",
#         "cbsa_code": "30300",
#         "cbsa_name": "Lewiston, ID-WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": "182",
#         "tribe_name": "Nez Perce Tribe, Idaho"
#     },
#     {
#         "state_code": "16",
#         "county_code": "069",
#         "site_number": "0009",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1986-01-01",
#         "close_date": "2002-06-28",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": null,
#         "measurement_scale_def": null,
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "1989-03-05",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0511",
#         "monitoring_agency": "Idaho Department Of Health And Welfare-Environment Division",
#         "si_id": 3575,
#         "latitude": 46.417778,
#         "longitude": -117.018611,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 225.0,
#         "probe_height": 11.0,
#         "pl_probe_location": null,
#         "local_site_name": null,
#         "address": "STATE OFFICE BLDG/1118 F ST",
#         "state_name": "Idaho",
#         "county_name": "Nez Perce",
#         "city_name": "Lewiston",
#         "cbsa_code": "30300",
#         "cbsa_name": "Lewiston, ID-WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": "182",
#         "tribe_name": "Nez Perce Tribe, Idaho"
#     },
#     {
#         "state_code": "16",
#         "county_code": "069",
#         "site_number": "0222",
#         "parameter_code": "81102",
#         "poc": 2,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "2006-05-01",
#         "close_date": "2007-04-30",
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "URBAN SCALE",
#         "measurement_scale_def": "4 KM TO 50 KM",
#         "monitoring_objective": "SOURCE ORIENTED",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "2006-05-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "182",
#         "monitoring_agency": "Nez Perce Tribe, Idaho",
#         "si_id": 93418,
#         "latitude": 46.438089,
#         "longitude": -116.905182,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.6,
#         "elevation": 235.53,
#         "probe_height": 2.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": null,
#         "address": "17500 NEZ PERCE ROAD",
#         "state_name": "Idaho",
#         "county_name": "Nez Perce",
#         "city_name": "Not in a city",
#         "cbsa_code": "30300",
#         "cbsa_name": "Lewiston, ID-WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": "182",
#         "tribe_name": "Nez Perce Tribe, Idaho"
#     },
#     {
#         "state_code": "53",
#         "county_code": "003",
#         "site_number": "0003",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1985-01-01",
#         "close_date": "1989-10-01",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": null,
#         "measurement_scale_def": null,
#         "monitoring_objective": "UNKNOWN",
#         "last_method_code": "051",
#         "last_method_description": "HI-VOL-SA321 - GRAVIMETRIC",
#         "last_method_begin_date": "1985-01-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "1136",
#         "monitoring_agency": "Washington State Department Of Ecology",
#         "si_id": 16454,
#         "latitude": 46.409605,
#         "longitude": -117.045991,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 256.0,
#         "probe_height": 6.0,
#         "pl_probe_location": null,
#         "local_site_name": null,
#         "address": "CF ADAMS HIGH/5TH & CHESTNUT",
#         "state_name": "Washington",
#         "county_name": "Asotin",
#         "city_name": "Clarkston",
#         "cbsa_code": "30300",
#         "cbsa_name": "Lewiston, ID-WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "53",
#         "county_code": "075",
#         "site_number": "0003",
#         "parameter_code": "88101",
#         "poc": 1,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2000-01-19",
#         "close_date": "2002-06-26",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "OTHER",
#         "last_method_code": "117",
#         "last_method_description": "R & P Model 2000 PM2.5 Sampler w/WINS - GRAVIMETRIC",
#         "last_method_begin_date": "2000-01-19",
#         "naaqs_primary_monitor": "Y",
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "1136",
#         "monitoring_agency": "Washington State Department Of Ecology",
#         "si_id": 16816,
#         "latitude": 46.72447,
#         "longitude": -117.18014,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 109305.56,
#         "elevation": 771.0,
#         "probe_height": 4.0,
#         "pl_probe_location": "TOP OF BUILDING",
#         "local_site_name": " PULLMAN - DEXTER AVE 4",
#         "address": "240 SE DEXTER (Pullman Administration Building)",
#         "state_name": "Washington",
#         "county_name": "Whitman",
#         "city_name": "Pullman",
#         "cbsa_code": "39420",
#         "cbsa_name": "Pullman, WA",
#         "csa_code": "446",
#         "csa_name": "Pullman-Moscow, WA-ID",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "16",
#         "county_code": "057",
#         "site_number": "0004",
#         "parameter_code": "81102",
#         "poc": 2,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1987-02-14",
#         "close_date": "1987-12-31",
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "MIDDLE SCALE",
#         "measurement_scale_def": "100 M TO 500 M",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "052",
#         "last_method_description": "HI-VOL-SA321A - GRAVIMETRIC",
#         "last_method_begin_date": "1987-02-14",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0511",
#         "monitoring_agency": "Idaho Department Of Health And Welfare-Environment Division",
#         "si_id": 3557,
#         "latitude": 46.73211,
#         "longitude": -116.997942,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 792.0,
#         "probe_height": 5.0,
#         "pl_probe_location": null,
#         "local_site_name": null,
#         "address": "HIGH SCHOOL ANNEX BLDG/325 E 3RD",
#         "state_name": "Idaho",
#         "county_name": "Latah",
#         "city_name": "Moscow",
#         "cbsa_code": "34140",
#         "cbsa_name": "Moscow, ID",
#         "csa_code": "446",
#         "csa_name": "Pullman-Moscow, WA-ID",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "16",
#         "county_code": "069",
#         "site_number": "0006",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1992-08-10",
#         "close_date": "1999-12-31",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": null,
#         "measurement_scale_def": null,
#         "monitoring_objective": "UNKNOWN",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "1992-08-10",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0511",
#         "monitoring_agency": "Idaho Department Of Health And Welfare-Environment Division",
#         "si_id": 3572,
#         "latitude": 46.429561,
#         "longitude": -116.992427,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 0.0,
#         "probe_height": null,
#         "pl_probe_location": null,
#         "local_site_name": null,
#         "address": "ISP BLDG/2700 N/S HWY 12-95",
#         "state_name": "Idaho",
#         "county_name": "Nez Perce",
#         "city_name": "Lewiston",
#         "cbsa_code": "30300",
#         "cbsa_name": "Lewiston, ID-WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": "182",
#         "tribe_name": "Nez Perce Tribe, Idaho"
#     },
#     {
#         "state_code": "16",
#         "county_code": "069",
#         "site_number": "0010",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1988-09-30",
#         "close_date": "1992-08-05",
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "1988-09-30",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0511",
#         "monitoring_agency": "Idaho Department Of Health And Welfare-Environment Division",
#         "si_id": 3576,
#         "latitude": 46.404051,
#         "longitude": -117.021268,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 880.0,
#         "probe_height": null,
#         "pl_probe_location": null,
#         "local_site_name": null,
#         "address": "1409 8TH STREET",
#         "state_name": "Idaho",
#         "county_name": "Nez Perce",
#         "city_name": "Lewiston",
#         "cbsa_code": "30300",
#         "cbsa_name": "Lewiston, ID-WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "53",
#         "county_code": "003",
#         "site_number": "0004",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1993-06-18",
#         "close_date": "2008-02-24",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "1993-06-18",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "1136",
#         "monitoring_agency": "Washington State Department Of Ecology",
#         "si_id": 16455,
#         "latitude": 46.425416,
#         "longitude": -117.060445,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 5.0,
#         "elevation": 250.0,
#         "probe_height": 6.0,
#         "pl_probe_location": null,
#         "local_site_name": "CLARKSTON - 13TH ST",
#         "address": "13TH ST AND PORT WAY (CLARKSTON STP)",
#         "state_name": "Washington",
#         "county_name": "Asotin",
#         "city_name": "Clarkston",
#         "cbsa_code": "30300",
#         "cbsa_name": "Lewiston, ID-WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "16",
#         "county_code": "069",
#         "site_number": "0012",
#         "parameter_code": "88101",
#         "poc": 1,
#         "parameter_name": "PM2.5 - Local Conditions",
#         "open_date": "2003-01-03",
#         "close_date": "2004-01-04",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "117",
#         "last_method_description": "R & P Model 2000 PM2.5 Sampler w/WINS - GRAVIMETRIC",
#         "last_method_begin_date": "2003-01-03",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0511",
#         "monitoring_agency": "Idaho Department Of Health And Welfare-Environment Division",
#         "si_id": 3578,
#         "latitude": 46.408352,
#         "longitude": -116.992533,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 30.36,
#         "elevation": 284.988,
#         "probe_height": 2.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": "Lewiston",
#         "address": "1200 29TH STREET",
#         "state_name": "Idaho",
#         "county_name": "Nez Perce",
#         "city_name": "Lewiston",
#         "cbsa_code": "30300",
#         "cbsa_name": "Lewiston, ID-WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": "182",
#         "tribe_name": "Nez Perce Tribe, Idaho"
#     },
#     {
#         "state_code": "16",
#         "county_code": "057",
#         "site_number": "0005",
#         "parameter_code": "88502",
#         "poc": 3,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2004-03-05",
#         "close_date": "2016-02-25",
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "URBAN SCALE",
#         "measurement_scale_def": "4 KM TO 50 KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "716",
#         "last_method_description": "PM2.5 VSCC w/No Correction Factor - TEOM Gravimetric 50 deg C",
#         "last_method_begin_date": "2015-04-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0511",
#         "monitoring_agency": "Idaho Department Of Health And Welfare-Environment Division",
#         "si_id": 3558,
#         "latitude": 46.72182,
#         "longitude": -116.960177,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 30.36,
#         "elevation": 800.7096,
#         "probe_height": 2.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": "Moscow",
#         "address": "1025 PLANT SCIENCES ROAD",
#         "state_name": "Idaho",
#         "county_name": "Latah",
#         "city_name": "Moscow",
#         "cbsa_code": "34140",
#         "cbsa_name": "Moscow, ID",
#         "csa_code": "446",
#         "csa_name": "Pullman-Moscow, WA-ID",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "16",
#         "county_code": "069",
#         "site_number": "0013",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "2006-05-01",
#         "close_date": "2007-04-30",
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "URBAN SCALE",
#         "measurement_scale_def": "4 KM TO 50 KM",
#         "monitoring_objective": "GENERAL/BACKGROUND",
#         "last_method_code": "063",
#         "last_method_description": "HI-VOL SA/GMW-1200 - GRAVIMETRIC",
#         "last_method_begin_date": "2006-05-01",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "182",
#         "monitoring_agency": "Nez Perce Tribe, Idaho",
#         "si_id": 91734,
#         "latitude": 46.3972,
#         "longitude": -116.8062,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 2.0,
#         "elevation": 339.14,
#         "probe_height": 4.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": null,
#         "address": "260 BEVER GRADE, LAPWAI",
#         "state_name": "Idaho",
#         "county_name": "Nez Perce",
#         "city_name": "Not in a city",
#         "cbsa_code": "30300",
#         "cbsa_name": "Lewiston, ID-WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": "182",
#         "tribe_name": "Nez Perce Tribe, Idaho"
#     },
#     {
#         "state_code": "16",
#         "county_code": "057",
#         "site_number": "0005",
#         "parameter_code": "88502",
#         "poc": 4,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2016-03-08",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "URBAN SCALE",
#         "measurement_scale_def": "4 KM TO 50 KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "731",
#         "last_method_description": "Met-One BAM-1020 W/PM2.5 SCC - Beta Attenuation",
#         "last_method_begin_date": "2016-11-16",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SPM",
#         "networks": null,
#         "monitoring_agency_code": "0511",
#         "monitoring_agency": "Idaho Department Of Health And Welfare-Environment Division",
#         "si_id": 3558,
#         "latitude": 46.72182,
#         "longitude": -116.960177,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 30.36,
#         "elevation": 800.7096,
#         "probe_height": 2.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": "Moscow",
#         "address": "1025 PLANT SCIENCES ROAD",
#         "state_name": "Idaho",
#         "county_name": "Latah",
#         "city_name": "Moscow",
#         "cbsa_code": "34140",
#         "cbsa_name": "Moscow, ID",
#         "csa_code": "446",
#         "csa_name": "Pullman-Moscow, WA-ID",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "16",
#         "county_code": "069",
#         "site_number": "0013",
#         "parameter_code": "88502",
#         "poc": 1,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2019-02-04",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "REGIONAL SCALE",
#         "measurement_scale_def": "50 TO HUNDREDS KM",
#         "monitoring_objective": "GENERAL/BACKGROUND",
#         "last_method_code": "171",
#         "last_method_description": "Met-one BAM-1022 W/PM2.5 SCC - Beta Attenuation",
#         "last_method_begin_date": "2019-02-04",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "TRIBAL",
#         "networks": null,
#         "monitoring_agency_code": "182",
#         "monitoring_agency": "Nez Perce Tribe, Idaho",
#         "si_id": 91734,
#         "latitude": 46.3972,
#         "longitude": -116.8062,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 2.0,
#         "elevation": 339.14,
#         "probe_height": 4.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": null,
#         "address": "260 BEVER GRADE, LAPWAI",
#         "state_name": "Idaho",
#         "county_name": "Nez Perce",
#         "city_name": "Not in a city",
#         "cbsa_code": "30300",
#         "cbsa_name": "Lewiston, ID-WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": "182",
#         "tribe_name": "Nez Perce Tribe, Idaho"
#     },
#     {
#         "state_code": "53",
#         "county_code": "003",
#         "site_number": "0004",
#         "parameter_code": "88502",
#         "poc": 8,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2019-12-03",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "171",
#         "last_method_description": "Met-one BAM-1022 W/PM2.5 SCC - Beta Attenuation",
#         "last_method_begin_date": "2019-12-03",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SPM",
#         "networks": null,
#         "monitoring_agency_code": "1136",
#         "monitoring_agency": "Washington State Department Of Ecology",
#         "si_id": 16455,
#         "latitude": 46.425416,
#         "longitude": -117.060445,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 5.0,
#         "elevation": 250.0,
#         "probe_height": 3.0,
#         "pl_probe_location": "GROUND LEVEL SUPPORT",
#         "local_site_name": "CLARKSTON - 13TH ST",
#         "address": "13TH ST AND PORT WAY (CLARKSTON STP)",
#         "state_name": "Washington",
#         "county_name": "Asotin",
#         "city_name": "Clarkston",
#         "cbsa_code": "30300",
#         "cbsa_name": "Lewiston, ID-WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "16",
#         "county_code": "057",
#         "site_number": "0004",
#         "parameter_code": "81102",
#         "poc": 1,
#         "parameter_name": "PM10 Total 0-10um STP",
#         "open_date": "1987-02-14",
#         "close_date": "1988-03-29",
#         "concurred_exclusions": null,
#         "dominant_source": "AREA",
#         "measurement_scale": "MIDDLE SCALE",
#         "measurement_scale_def": "100 M TO 500 M",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "064",
#         "last_method_description": "HI-VOL-SA/GMW-321-B - GRAVIMETRIC",
#         "last_method_begin_date": "1987-02-14",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": null,
#         "networks": null,
#         "monitoring_agency_code": "0511",
#         "monitoring_agency": "Idaho Department Of Health And Welfare-Environment Division",
#         "si_id": 3557,
#         "latitude": 46.73211,
#         "longitude": -116.997942,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 0.0,
#         "elevation": 792.0,
#         "probe_height": 5.0,
#         "pl_probe_location": null,
#         "local_site_name": null,
#         "address": "HIGH SCHOOL ANNEX BLDG/325 E 3RD",
#         "state_name": "Idaho",
#         "county_name": "Latah",
#         "city_name": "Moscow",
#         "cbsa_code": "34140",
#         "cbsa_name": "Moscow, ID",
#         "csa_code": "446",
#         "csa_name": "Pullman-Moscow, WA-ID",
#         "tribal_code": null,
#         "tribe_name": null
#     },
#     {
#         "state_code": "53",
#         "county_code": "003",
#         "site_number": "0004",
#         "parameter_code": "88502",
#         "poc": 4,
#         "parameter_name": "Acceptable PM2.5 AQI & Speciation Mass",
#         "open_date": "2007-03-07",
#         "close_date": null,
#         "concurred_exclusions": null,
#         "dominant_source": null,
#         "measurement_scale": "NEIGHBORHOOD",
#         "measurement_scale_def": "500 M TO 4KM",
#         "monitoring_objective": "POPULATION EXPOSURE",
#         "last_method_code": "771",
#         "last_method_description": "Correlated Radiance Research M903 With Heated Inlet - Nephelometry",
#         "last_method_begin_date": "2007-03-07",
#         "naaqs_primary_monitor": null,
#         "qa_primary_monitor": null,
#         "monitor_type": "SLAMS",
#         "networks": null,
#         "monitoring_agency_code": "1136",
#         "monitoring_agency": "Washington State Department Of Ecology",
#         "si_id": 16455,
#         "latitude": 46.425416,
#         "longitude": -117.060445,
#         "datum": "WGS84",
#         "lat_lon_accuracy": 5.0,
#         "elevation": 250.0,
#         "probe_height": 6.0,
#         "pl_probe_location": null,
#         "local_site_name": "CLARKSTON - 13TH ST",
#         "address": "13TH ST AND PORT WAY (CLARKSTON STP)",
#         "state_name": "Washington",
#         "county_name": "Asotin",
#         "city_name": "Clarkston",
#         "cbsa_code": "30300",
#         "cbsa_name": "Lewiston, ID-WA",
#         "csa_code": null,
#         "csa_name": null,
#         "tribal_code": null,
#         "tribe_name": null
#     }
# ]

# %% [markdown]
# Since there are no stations in Lewiston, I found stations in the 50 mile radius with data starting from 1986 to 2023. The information for these stations are below
#
# "state_code": "16",
# "county_code": "069",
# "open_date": "1986-01-01",
# "close_date": "2002-06-28",
#
# "state_code": "53",
# "county_code": "075",
# "open_date": "2002-10-01",
# "close_date": '2023-10-31'

# %%
# This dictionary defines the station for each year under study for which there exists information
stations_dict = {
    '1986': '16069',
    '1987': '16069',
    '1988': '16069',
    '1989': '16069',
    '1990': '16069',
    '1991': '16069',
    '1992': '16069',
    '1993': '16069',
    '1994': '16069',
    '1995': '16069',
    '1996': '16069',
    '1997': '16069',
    '1998': '16069',
    '1999': '16069',
    '2000': '16069',
    '2001': '16069',
    '2002': '16069',
    '2003': '53075',
    '2004': '53075',
    '2005': '53075',
    '2006': '53075',
    '2007': '53075',
    '2008': '53075',
    '2009': '53075',
    '2010': '53075',
    '2011': '53075',
    '2012': '53075',
    '2013': '53075',
    '2014': '53075',
    '2015': '53075',
    '2016': '53075',
    '2017': '53075',
    '2018': '53075',
    '2019': '53075',
    '2020': '53075',
    '2021': '53075',
    '2022': '53075',
    '2023': '53075'
}

# %%
# Numpy is required to be imported for the np.mean method used below
import numpy as np

# %%
# aqi_year is a dictionary that is used to store the year and the average aqi estimate for all the months/days for
# that year
aqi_year = {}
for year, station in stations_dict.items():
    request_data = AQS_REQUEST_TEMPLATE.copy()
    request_data['email'] = USERNAME
    request_data['key'] = APIKEY
    request_data['param'] = AQI_PARAMS_PARTICULATES
    request_data['state'] = station[:2]
    request_data['county'] = station[2:]
    # define the begin date as the first of January
    begin_date = year + '0101'
    # takes care of the two cases where the end date needs to be defined according to what information is 
    # available at that station
    if station == '16069' and year == '2002':
        end_date = year + '0628'
    if station == '53075' and year == '2023':
        end_date = year + '1031'
    else:
        end_date = year + '1231'
    # this request is only for the particulate matter as there was no information returned for the gaseous 
    particulate_aqi = request_daily_summary(request_template=request_data, begin_date=begin_date, end_date=end_date)
    aqi_list = []
    if particulate_aqi["Header"][0]['status'] == "Success": # if the API status was successful
        for i in range(len(particulate_aqi['Data'])):
            if particulate_aqi['Data'][i]['aqi'] is not None:
                aqi_list.append(particulate_aqi['Data'][i]['aqi'])
        avg_aqi = np.mean(aqi_list)
        aqi_year[year] = avg_aqi
    elif particulate_aqi["Header"][0]['status'].startswith("No data "):
        print("There is no data")

# %%
# display the aqi_year dictionary with the averaged out AQI values for each year with available data
aqi_year
# Out:
# {'1986': 34.51851851851852,
#  '1987': 36.03448275862069,
#  '1988': 36.22222222222222,
#  '1989': 33.60683760683761,
#  '1990': 29.28421052631579,
#  '1991': 38.77777777777778,
#  '1992': 27.69747899159664,
#  '1993': 33.68595041322314,
#  '1994': 28.33613445378151,
#  '1995': 25.552845528455286,
#  '1996': 23.96694214876033,
#  '1997': 25.72641509433962,
#  '1998': 24.47747747747748,
#  '1999': 34.77477477477478,
#  '2000': 38.44748858447488,
#  '2001': 34.02832618025751,
#  '2002': 31.381132075471697,
#  '2003': 21.96712328767123,
#  '2004': 22.13565536205316,
#  '2005': 19.678341013824884,
#  '2006': 21.56583969465649,
#  '2007': 21.169617893755824,
#  '2008': 21.0757299270073,
#  '2009': 20.994366197183098,
#  '2010': 18.10810810810811,
#  '2011': 18.32264150943396,
#  '2012': 20.44177093358999,
#  '2013': 22.351224105461394,
#  '2014': 19.526621490803485,
#  '2015': 22.881278538812786,
#  '2016': 16.399803536345775,
#  '2017': 22.630940343781596,
#  '2018': 21.763012181616833,
#  '2019': 17.247895229186156,
#  '2020': 17.84540636042403,
#  '2021': 21.00349956255468,
#  '2022': 19.945866141732285,
#  '2023': 15.791666666666666}

# %%
# Save this result into a file to read into the other notebook
with open('aqi_lewiston.json', 'w') as file:
    json.dump(aqi_year, file)
